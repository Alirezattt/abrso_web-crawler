# %%
import requests
import time
import random
import os 
from fake_useragent import UserAgent

# %%
common = ["خودرو", "ماشین"]
separate = ["تزئینات","ردیاب","اسپرت","صوتی","امنیت","دزدگیر","لوازم%20اسپرت","صوتی%20و%20تصویری"]
combinations = []

for i in common :
    for j in separate :
        combinations.append(f"{j}%20{i}")

path = "./torob"
if not os.path.exists(path):
    os.mkdir(path)

all_ids = set()
for i in combinations :
    Keyword = i.replace("%20", " ")
    
    url = f"https://api.torob.com/v4/internet-shop/list/?page=0&q={i}&size=1000&show_blocks=true&shop_type=all&source=next_desktop"


    

    counter = 0

    while 5 > counter :


        response = requests.get(url)
        data = response.json()
        print(data)
        data["id"]
        data["name"]
        data["domain"]
        data["shop_type"]
        data["city"]
        url

        if data["next"] :
            break
        


        url = data["next"]
        counter +=1
        time.sleep(random.uniform(2, 5))
"https://api.torob.com/v4/internet-shop/details/?id=272310&source=next_desktop"

# %%
import requests

url = "https://api.torob.com/v4/internet-shop/details/?id=272310&source=next_desktop"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:144.0) Gecko/20100101 Firefox/144.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Referer": "https://torob.com/",
    "Origin": "https://torob.com",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "Connection": "keep-alive",
    "Priority": "u=4",
    "TE": "trailers"
}

cookies = {
    "new_question_bucket":"0.646936",
    "new_question_visibility":"false",
    "_ga_RWKMFFVXJX":"GS2.1.s1761206662$o3$g1$t1761207313$j5$l0$h1129999523",
    "_ga":"GA1.1.265981767.1761132154",
    "search_session":"nfrsywmrjwnmzkmmpwpumppozqdbykaz",
    "display_mode":"",
    "is_torob_user_logged_in":"False",
    "trb_clearance":"8Stij9R3s99Y_8gn2JcHXEHi19PecMHovl3WP6hMOz5kL0_czsE_l5_L1P38rF8sjrdQUjHGaoIMhkHS7AVJPQ2qI5edJPnQvPoHWoEZK4Svx3RanA48XHbQvzfB5p9KYS19JTjkwaZyC4p7AQmaXTuv0tBD54KdbO1BEFYnVuvpBCqUX5gJhQ"
}

response = requests.get(url, headers=headers, cookies=cookies)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>آیا شما یک ربات هستید؟‌ | ترب</title>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
#
#     <link rel="dns-prefetch" href="//fonts.gstatic.com">
#     <link href="https://fonts.googleapis.com/css?family=Montserrat:400,500,600,900" rel="stylesheet">
#     <link rel="preconnect" href="https://fonts.googleapis.com">
#     <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#     <link href="https://fonts.googleapis.com/css2?family=Noto+Sans+Arabic:wght@100..900&display=swap" rel="stylesheet">
#
#     <script src="https://challenges.cloudflare.com/turnstile/v0/api.js?onload=_turnstileCb" async defer></script>
#     <style type="text/css">
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
url = "https://api.torob.com/v4/internet-shop/details/?id=272310&source=next_desktop"
url = f"https://api.torob.com/v4/internet-shop/list/?page=0&q={"دزدگیر"}&size=1000&show_blocks=true&shop_type=all&source=next_desktop"



# Set up Chrome options
options = Options()
# options.add_argument("--headless")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)


# Navigate to the API (can scrape HTML, but for XHR/fetch, more steps needed)
driver.get(url)
element = driver.find_element(By.XPATH,"/html/body/pre")
print(element.text)
time.sleep(random.uniform(3,5))

driver.quit()
# Out:
# {"count":86,"next":null,"previous":null,"results":[{"id":188812,"name":"دزدگیر بازار","domain":"dozdgirbazar.ir","block_partner":true,"shop_logo":"https://storage3.torob.com/backend-api/internet_shop/logos/c54d296ae533.png","is_marketplace":false,"shop_type":"online-offline","city":"تهران","guarantee_info":{"status":"disabled"},"fixed_priority":false,"upvotes":0,"downvotes":0,"score_percentile":0,"primaryColor":"#ffffff","accentColor":"#ffffff"},{"id":43495,"name":"دوربین و دزدگیر عدنان","domain":"adnanshop.ir","block_partner":false,"shop_logo":"https://storage3.torob.com/backend-api/internet_shop/logos/f2feaff7dfa2.png","is_marketplace":false,"shop_type":"online-offline","city":"لامرد","guarantee_info":{"status":"disabled"},"fixed_priority":false,"upvotes":0,"downvotes":0,"score_percentile":0,"primaryColor":"#ffffff","accentColor":"#ffffff"},{"id":211416,"name":"دزدگیر نوین","domain":"dzdgir-novin.ir","block_partner":true,"shop_logo":"https://storage3.torob.com/backend-api/internet_
# ...
